# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
## Load model

# %%
from tensorflow.keras.models import load_model

# %%
loaded_model = load_model(r"C:\Users\ishit\OneDrive\Desktop\Project\Plant_disease_detector_copy/trainn_model.keras")

# %%
loaded_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 128, 128, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 126, 126, 32)        │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 63, 63, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 63, 63, 64)          │          18,496 │
# ...

# %%
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
##Visualizaing Single Image of Test Set

# %%
import cv2
image_path =r"test\Potato___Late_blight\0acdc2b2-0dde-4073-8542-6fca275ab974___RS_LB 4857.JPG"
#Reading Image
img = cv2.imread(image_path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB) #Converting BGR to RGB
#display image
plt.imshow(img)
plt.title("Test Image")
plt.show()

# %%
"""""
#import cv2

# Read the image
image_path = r"test/Potato___Early_blight/001187a0-57ab-4329-baff-e7246a9edeb0___RS_Early.B 8178.JPG"
img = cv2.imread(image_path)

# Check the data type of the image
print("Image data type:", img.dtype)"""
# Out:
# '""\n#import cv2\n\n# Read the image\nimage_path = r"test/Potato___Early_blight/001187a0-57ab-4329-baff-e7246a9edeb0___RS_Early.B 8178.JPG"\nimg = cv2.imread(image_path)\n\n# Check the data type of the image\nprint("Image data type:", img.dtype)'

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(128,128))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
input_arr = np.array([input_arr]) #convert single image into batch
print(input_arr.shape) #1=batch
# Out:
# (1, 128, 128, 3)

# %%
prediction = loaded_model.predict(input_arr)# 1 row 10 column
prediction,prediction.shape
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 531ms/step
# (array([[8.75697911e-01, 1.08723138e-02, 4.28047679e-06, 1.00322645e-02,
#          1.02820598e-01, 4.70497582e-07, 7.21521792e-06, 2.86837167e-04,
#          9.25451059e-06, 2.68871750e-04]], dtype=float32),
#  (1, 10))

# %%
result_index = np.argmax(prediction)
result_index
# Out:
# 0

# %%
class_name =[ 'Potato___Late_blight',
 'Potato___healthy',
 'Tomato_Bacterial_spot',
 'Tomato_Early_blight',
 'Tomato_Late_blight',
 'Tomato_Leaf_Mold',
 'Tomato_Septoria_leaf_spot',
 'Tomato_Spider_mites_Two_spotted_spider_mite',
 'Tomato__Tomato_YellowLeaf__Curl_Virus',
 'Tomato_healthy']

# %%
#Display Result of disease prediction
model_prediction = class_name[result_index]
plt.imshow(img)
plt.title(f"Disease Name: {model_prediction}")
plt.xticks([])
plt.yticks([])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
